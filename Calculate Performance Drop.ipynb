# %%
print("Baseline on MIMIC IV Mortality")
print("AUROC drop")
drop = (0.878 - 0.785)/0.878*100
drop_wide = (0.878 + 0.013 - 0.785 + 0.016)/0.878*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.427 - 0.250)/0.427*100
drop_wide = (0.427 + 0.029 - 0.250 + 0.021)/0.427*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("LR on MIMIC IV")
print("AUROC drop")
drop = (0.878 - 0.821)/0.878*100
drop_wide = (0.878 + 0.013 - 0.821 + 0.016)/0.878*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.427 - 0.283)/0.427*100
drop_wide = (0.427 + 0.029 - 0.283 + 0.024)/0.427*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("GB on MIMIC IV")
print("AUROC drop")
drop = (0.899 - 0.867)/0.899*100
drop_wide = (0.899 + 0.011 - 0.867 + 0.014)/0.899*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.479 - 0.364)/0.479*100
drop_wide = (0.479 + 0.029 - 0.364 + 0.026)/0.479*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("RF on MIMIC IV")
print("AUROC drop")
drop = (0.900 - 0.862)/0.900*100
drop_wide = (0.900 + 0.010 - 0.862 + 0.014)/0.900*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.477 - 0.373)/0.477*100
drop_wide = (0.477 + 0.032 - 0.373 + 0.033)/0.477*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("NN on MIMIC IV")
print("AUROC drop")
drop = (0.803 - 0.612)/0.803*100
drop_wide = (0.803 + 0.012 - 0.612 + 0.015)/0.803*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.422 - 0.288)/0.422*100
drop_wide = (0.422 + 0.051 - 0.288 + 0.042)/0.422*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()
# Out:
# Baseline on MIMIC IV Mortality
# AUROC drop
# 10.592255125284735
# 3.3029612756264246
# AURPC drop
# 41.4519906323185
# 11.709601873536307
#
# LR on MIMIC IV
# AUROC drop
# 6.492027334851942
# 3.3029612756264246
# AURPC drop
# 33.723653395784545
# 12.412177985948482
#
# GB on MIMIC IV
# AUROC drop
# 3.5595105672969996
# 2.780867630700779
# AURPC drop
# 24.008350730688935
# 11.48225469728602
#
# RF on MIMIC IV
# AUROC drop
# 4.222222222222226
# 2.666666666666667
# AURPC drop
# 21.802935010482177
# 13.626834381551365
#
# NN on MIMIC IV
# AUROC drop
# 23.78580323785804
# 3.3623910336239113
# AURPC drop
# 31.753554502369667
# 22.037914691943136

# %%
print("Baseline on MIMIC IV ICU")
print("AUROC drop")
drop = (0.898 - 0.846)/0.898*100
drop_wide = (0.898 + 0.009 - 0.846 + 0.007)/0.898*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.818 - 0.729)/0.818*100
drop_wide = (0.818 + 0.014 - 0.729 + 0.015)/0.818*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("LR on MIMIC IV")
print("AUROC drop")
drop = (0.898 - 0.857)/0.898*100
drop_wide = (0.898 + 0.009 - 0.857 + 0.010)/0.898*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.818 - 0.747)/0.818*100
drop_wide = (0.818 + 0.014 - 0.747 + 0.017)/0.818*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("GB on MIMIC IV")
print("AUROC drop")
drop = (0.910 - 0.880)/0.910*100
drop_wide = (0.910 + 0.008 - 0.880 + 0.008)/0.910*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.837 - 0.775)/0.837*100
drop_wide = (0.837 + 0.013 - 0.775 + 0.014)/0.837*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("RF on MIMIC IV")
print("AUROC drop")
drop = (0.902 - 0.880)/0.902*100
drop_wide = (0.902 + 0.008 - 0.880 + 0.009)/0.902*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.824 - 0.772)/0.824*100
drop_wide = (0.824 + 0.013 - 0.772 + 0.013)/0.824*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()

print("NN on MIMIC IV")
print("AUROC drop")
drop = (0.799 - 0.601)/0.799*100
drop_wide = (0.799 + 0.009 - 0.601 + 0.010)/0.799*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print("AURPC drop")
drop = (0.779 - 0.536)/0.779*100
drop_wide = (0.779 + 0.013 - 0.536 + 0.021)/0.779*100
drop_diff = drop_wide - drop
print(drop)
print(drop_diff)
print()
# Out:
# Baseline on MIMIC IV ICU
# AUROC drop
# 5.790645879732744
# 1.781737193763922
# AURPC drop
# 10.880195599022002
# 3.5452322738386304
#
# LR on MIMIC IV
# AUROC drop
# 4.565701559020049
# 2.1158129175946554
# AURPC drop
# 8.679706601466988
# 3.789731051344745
#
# GB on MIMIC IV
# AUROC drop
# 3.2967032967032996
# 1.7582417582417587
# AURPC drop
# 7.407407407407401
# 3.225806451612904
#
# RF on MIMIC IV
# AUROC drop
# 2.4390243902439046
# 1.8847006651884701
# AURPC drop
# 6.310679611650478
# 3.1553398058252444
#
# NN on MIMIC IV
# AUROC drop
# 24.78097622027535
# 2.3779724655819834
# AURPC drop
# 31.193838254172015
# 4.364569961489096
